# %%
import pyodbc
from sqlalchemy import create_engine
import urllib

# %%
params = urllib.parse.quote_plus(r'Driver={ODBC Driver 13 for SQL Server};Server=tcp:devsqlservermf.database.windows.net,1433;Database=devsqldatabasemf;Uid=mattiaficarelli;Pwd=Butler30039508;Encrypt=yes;TrustServerCertificate=no;Connection Timeout=30;')
conn_str = 'mssql+pyodbc:///?odbc_connect={}'.format(params)
engine_azure = create_engine(conn_str,echo=True)

print('connection is ok')
# Out:
# connection is ok

# %%
engine_azure.execute("SELECT TOP (10) * FROM [dbo].[eps_usage_eps_utilisation_month_prop]")
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# File c:\Users\mattia.ficarelli_nhs\.virtualenvs\restapi_flask-8CKOjWfa\lib\site-packages\sqlalchemy\engine\base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File c:\Users\mattia.ficarelli_nhs\.virtualenvs\restapi_flask-8CKOjWfa\lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File c:\Users\mattia.ficarelli_nhs\.virtualenvs\restapi_flask-8CKOjWfa\lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# ...
